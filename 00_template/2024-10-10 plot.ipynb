# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.plot import *
from numpy.random import rand

# %%
plt.figure(figsize=figsize_small)
plt.plot(rand(5), label='line 1')  
plt.plot(rand(5), label='line 2')  
plt.legend()
plt.ylabel('some numbers')
plt.savefig('fig/2024-10-01 line plot.pdf')
plt.show()

# %%
plt.figure()
plt.imshow(rand(10, 10), interpolation='bicubic')
plt.colorbar()
plt.savefig('fig/2024-10-01 img plot.pdf')
plt.show()
